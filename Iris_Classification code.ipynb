# %% [markdown]
# Project on Iris Flowers Classification

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# Loading Iris dataset

# %%
iris=pd.read_csv("E:\python\Iris_Classification\iris.csv")

# %%
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
print(iris.dtypes)
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
iris.isnull()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.size
# Out:
# 750

# %%
iris['Species'].value_counts()
# Out:
# Species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
print(iris.groupby('Species').size())
# Out:
# Species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %% [markdown]
# Exploratory Data Analysis on Iris dataset

# %% [markdown]
# 1.Relationship between Species and Sepal length

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Species', y='Sepal.Length', data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='Sepal.Length'>

# %% [markdown]
# 2.Realtion between Species and Sepal Width

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Species', y='Sepal.Width', data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='Sepal.Width'>

# %% [markdown]
# 3.Relation between Species and Petal Length

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Species', y='Petal.Length', data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='Petal.Length'>

# %% [markdown]
# 4.Relation between Species and Petal Width

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Species', y='Petal.Width', data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='Petal.Width'>

# %% [markdown]
# PAIR PLOT

# %%
sns.pairplot(data=iris,hue='Species')

# %% [markdown]
# Categorical plot

# %%
plt.figure(figsize=(15,15))
sns.catplot(x='Species',y='Sepal.Width',data=iris.sort_values('Sepal.Width'))

# %%
sns.boxplot(data=iris,palette='rainbow')
plt.show()

# %%
X=iris[['Sepal.Length','Sepal.Width','Petal.Length','Petal.Width']]
y=iris[['Species']]

# %% [markdown]
# Applying Training and Testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30)

# %%
len(X_train)/len(X)
# Out:
# 0.7

# %%
len(y_test)/len(y)
# Out:
# 0.3

# %%
from sklearn.linear_model import LinearRegression

# %%
irislr=LinearRegression()

# %%
X
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 1 columns]

# %%
plt.plot(iris['Species'])
plt.plot(iris['Petal.Length'])

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()

# %%
plt.plot(iris['Species'])
plt.plot(iris['Petal.Width'])

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()

# %%
plt.plot(iris['Species'])
plt.plot(iris['Sepal.Length'])

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()

# %%
plt.plot(iris['Species'])
plt.plot(iris['Sepal.Width'])

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()
